# %%
from matplotlib import pyplot as plt

years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# create a line chart, years on x-axis, gdp on y-axis
plt.plot(years, gdp, color='green', marker='o', linestyle='solid')

# add a title
plt.title("Nominal GDP")

# add a label to the y-axis
plt.ylabel("Billions of $")
plt.show()

# %%
import pandas as pd
df = pd.read_csv('https://github.com/langsaree/awesome-datasets/raw/master/iris.csv')

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width   class
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.tail()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width      class
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df[['sepal.length','sepal.width']]
# Out:
#      sepal.length  sepal.width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
import pandas as pd
df1 = pd.read_excel('https://github.com/langsaree/awesome-datasets/raw/master/Superstore.xlsx')

# %%
df1
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df1.sample(10)
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 6775   23984  Not Specified      0.10        2.78           1.25         2487
# 5848   23685           High      0.07      115.99           2.50         2139
# 4361   26109       Critical      0.08       55.48           6.79         1639
# 9313   25007            Low      0.07       34.58           8.99         3368
# 5165   18159            Low      0.06        3.58           1.63         1933
# 8234   21499            Low      0.01       10.14           2.27         3000
# 4446   23745            Low      0.04      300.98          64.73         1675
# 5348   25127            Low      0.04        6.48           9.17         1991
# 2848   23469            Low      0.04       65.99           2.50         1103
# 7618   22094            Low      0.03       24.92          12.98         2781
#
#                  Customer Name       Ship Mode Customer Segment  \
# ...

# %%
data1 = df1['Order Date']
data2 = df1['Profit']

# %%
data1.sample(10)
# Out:
# 1399   2011-02-26
# 3188   2010-02-04
# 4229   2012-01-03
# 1513   2011-03-13
# 896    2013-03-08
# 6296   2010-03-16
# 8845   2012-04-11
# 964    2012-10-09
# 3106   2013-11-26
# 3862   2011-03-15
# Name: Order Date, dtype: datetime64[ns]

# %%
data2.head()
# Out:
# 0      1.3200
# 1      4.5600
# 2    -47.6400
# 3    -30.5100
# 4    998.2023
# Name: Profit, dtype: float64

# %%
data2.describe
# Out:
# <bound method NDFrame.describe of 0          1.320000
# 1          4.560000
# 2        -47.640000
# 3        -30.510000
# 4        998.202300
#            ...
# 9421     137.860000
# 9422     -39.070000
# 9423   -1225.029097
# 9424     349.485000
# 9425      78.062400
# Name: Profit, Length: 9426, dtype: float64>

# %%
data11 = data1[:10]
data22 = data2[:10]

# %%
data11
# Out:
# 0   2012-05-28
# 1   2010-07-07
# 2   2011-07-27
# 3   2011-07-27
# 4   2011-07-27
# 5   2011-11-09
# 6   2013-07-01
# 7   2010-12-13
# 8   2012-05-12
# 9   2011-05-26
# Name: Order Date, dtype: datetime64[ns]

# %%
data22
# Out:
# 0       1.3200
# 1       4.5600
# 2     -47.6400
# 3     -30.5100
# 4     998.2023
# 5    1388.0523
# 6    1001.4453
# 7    4390.3665
# 8    -141.2600
# 9    1045.4673
# Name: Profit, dtype: float64

# %%
from matplotlib import pyplot as plt 
plt.plot(data1, data2, color='green', marker='o', linestyle='solid')

# %%
from matplotlib import pyplot as plt 
plt.plot(data11, data22, color='green', marker='o', linestyle='solid')
