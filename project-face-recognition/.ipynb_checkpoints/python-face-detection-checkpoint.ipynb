# %%
import cv2
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
curl -o 'http://dsdi.msu.ac.th/data/programming/etc/haar-xml/haarcascade_frontalface_default.xml'
# Out:
#   File "<ipython-input-1-35a8653d5bb0>", line 1
#     curl -o 'http://dsdi.msu.ac.th/data/programming/etc/haar-xml/haarcascade_frontalface_default.xml'
#                                                                                                     ^
# SyntaxError: invalid syntax

# %%
ls -al
# Out:
# total 14616
# drwxr-xr-x   9 kholed  staff      288 Aug 27 13:34 ./
# drwxr-xr-x  22 kholed  staff      704 Aug 27 13:32 ../
# drwxr-xr-x   3 kholed  staff       96 Aug 28  2019 .ipynb_checkpoints/
# -rw-r--r--   1 kholed  staff     3657 Aug 28  2019 Kholed_Langsari.jpg
# -rw-r--r--   1 kholed  staff  6015928 Aug 28  2019 file-20190801-169680-f0a4c1.jpg
# -rw-r--r--   1 kholed  staff   930127 Aug 28  2019 haarcascade_frontalface_default.xml
# -rw-r--r--   1 kholed  staff    26265 Aug 28  2019 jia-jia-2.jpg
# -rw-r--r--   1 kholed  staff   105543 Aug 27 00:53 python-face-detection.ipynb
# -rw-r--r--   1 kholed  staff     2975 Aug 28  2019 python-face-detection2.ipynb

# %%
import cv2
cascPath = "haarcascade_frontalface_default.xml"
faceCascade = cv2.CascadeClassifier(cascPath)

# %%
img = cv2.imread("jia-jia-2.jpg")

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
faces = faceCascade.detectMultiScale(img,scaleFactor=1.1,minNeighbors=5,minSize=(30, 30),flags=cv2.CASCADE_SCALE_IMAGE)

# %%
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
    crop_img = img[y:y+h, x:x+w]

# %%
plt.axis('off')
plt.imshow(crop_img)

# %%
import requests
import base64

# %%
# !apt update
# Out:
# apt: invalid flag: update
# Usage: apt <apt and javac options> <source files>
# where apt options include:
#   -classpath <path>          Specify where to find user class files and annotation processor factories
#   -cp <path>                 Specify where to find user class files and annotation processor factories
#   -d <path>                  Specify where to place processor and javac generated class files
#   -s <path>                  Specify where to place processor generated source files
#   -source <release>          Provide source compatibility with specified release
#   -version                   Version information
#   -help                      Print a synopsis of standard options; use javac -help for more options
#   -X                         Print a synopsis of nonstandard options
#   -J<flag>                   Pass <flag> directly to the runtime system
#   -A[key[=value]]            Options to pass to annotation processors
# ...
