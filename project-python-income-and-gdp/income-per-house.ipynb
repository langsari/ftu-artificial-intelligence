# %%
import pandas as pd

# %%
path = 'income-per-house.xlsx'
df = pd.read_excel("income-per-house.xlsx")

# %%
df
# Out:
#        ภาค และจังหวัด  Unnamed: 1     2541     2543     2545     2547  \
# 0                 NaN         NaN   1998.0   2000.0   2002.0   2004.0
# 1                 NaN         NaN      NaN      NaN      NaN      NaN
# 2     ทั่วราชอาณาจักร         NaN  12492.0  12150.0  13736.0  14963.0
# 3            ตอนพิเศษ         NaN  24929.0  25242.0  28239.0  28135.0
# 4       กรุงเทพมหานคร         NaN  26054.0  26909.0  29589.0  29843.0
# ..                ...         ...      ...      ...      ...      ...
# 80               ตรัง         NaN  12973.0  12782.0  14332.0  17038.0
# 81             พัทลุง         NaN  12315.0  11550.0  10820.0  14985.0
# 82            ปัตตานี         NaN  10737.0   9759.0   9702.0  11837.0
# 83               ยะลา         NaN   7560.0   9932.0  10018.0  11886.0
# 84           นราธิวาส         NaN   6281.0   7802.0   7603.0   9240.0
#
#        2549     2550     2552     2554     2556          2558  \
# 0    2006.0   2007.0   2009.0   2011.0   2013.0   2015.000000
# ...

# %%
df.[2]
df
# Out:
#   File "<ipython-input-13-06c7bee806e0>", line 1
#     df.[2]
#        ^
# SyntaxError: invalid syntax
