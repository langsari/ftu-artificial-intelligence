# %%
import pandas as pd
df=pd.read_csv('https://github.com/langsaree/awesome-datasets/raw/master/iris.csv')

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width   class
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df = df.alter(sepal.length=sepal_length)
# Out:
#   File "<ipython-input-6-43be99065802>", line 1
#     df = df.alter(sepal.length=sepal_length)
#                  ^
# SyntaxError: keyword can't be an expression

# %%
df.drop(columns=['variety'])
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
# import sciencki learn for use kmean
from sklearn.cluster import KMeans

#import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# use k-mean
# use petal_length, petal_width attribute

model=KMeans(n_clusters=4)
X=df[['petal.length','petal.width']]
model.fit(X)
model.cluster_centers_
sns.scatterplot(data=df, x='petal.length', y='petal.width')
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], color='.1', marker='D')
