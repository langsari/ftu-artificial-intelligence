# %%
#เรียนรู้ การดึงข้อมูลจาก Google Sheet
from IPython.display import IFrame, YouTubeVideo, SVG, HTML
YouTubeVideo('sDUJxIZn0W4', 400,300)
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/sDUJxIZn0W4"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import pandas as pd
print(f'pandas version: {pd.__version__}')
# Out:
# pandas version: 0.24.2

# %%
from datetime import datetime
str(datetime.now())
# Out:
# '2018-03-07 09:56:48.605620'

# %% [markdown]
# ## The greatest films of all time: download the data
# https://www.theguardian.com/news/datablog/2010/oct/16/greatest-films-of-all-time
#
# https://docs.google.com/spreadsheets/d/1okTb4MTllkDWlj0daHNfA8RwOPhLQkWtpQN_znJJJmk/edit?hl=en&hl=en#gid=0

# %%
# https://docs.google.com/spreadsheets/d/1okTb4MTllkDWlj0daHNfA8RwOPhLQkWtpQN_znJJJmk/edit?hl=en&hl=en#gid=2
url='https://docs.google.com/spreadsheets/d/1okTb4MTllkDWlj0daHNfA8RwOPhLQkWtpQN_znJJJmk/export?gid=2&format=csv'
df=pd.read_csv(url, index_col='Film')
df.head()
# Out:
#                   Entry     Cat         Director  \
# Film
# Annie Hall            1  Comedy      Woody Allen
# Borat                 2  Comedy    Larry Charles
# Some Like it Hot      3  Comedy     Billy Wilder
# Team America          4  Comedy      Trey Parker
# Dr Strangelove        5  Comedy  Stanley Kubrick
#
#                                                      Leading actors  \
# Film
# Annie Hall        Carol Kane, Diane Keaton, Paul Simon, Tony Rob...
# Borat             Ken Davitian, Pamela Anderson , Sacha Baron Cohen
# Some Like it Hot  George Raft, Jack Lemmon, Joe E Brown, Marilyn...
# Team America                Kristen Miller, Matt Stone, Trey Parker
# Dr Strangelove       George C Scott, Peter Sellers, Sterling Hayden
#
#                   Year of cinema release  Oscars won  \
# Film
# Annie Hall                          1977         4.0
# Borat                               2006         NaN
# Some Like it Hot                    1959         1.0
# ...

# %%
# https://docs.google.com/spreadsheets/d/1okTb4MTllkDWlj0daHNfA8RwOPhLQkWtpQN_znJJJmk/edit?hl=en&hl=en#gid=2
url='https://docs.google.com/spreadsheets/d/1okTb4MTllkDWlj0daHNfA8RwOPhLQkWtpQN_znJJJmk/export?gid=5&format=csv'
df=pd.read_csv(url, index_col='Film')
df.head()
# Out:
#                   Entry         Director  \
# Film
# 2001                  1  Stanley Kubrick
# Metropolis            2       Fritz Lang
# Blade Runner          3     Ridley Scott
# Alien                 4     Ridley Scott
# The Wizard of Oz      5   Victor Fleming
#
#                                                      Leading actors  \
# Film
# 2001              Daniel Richter, Gary Lockwood, Keir Dullea, Wi...
# Metropolis        Alfred Abel, Brigitte Helm, Gustav Frohlich, G...
# Blade Runner                Harrison Ford, Rutger Hauer, Sean Young
# Alien             Ian Holm, John Hurt, Sigourney Weaver, Tom Ske...
# The Wizard of Oz  Bert Lahr, Frank Morgan, Jack Haley, Judy Garl...
#
#                  Year of cinema release No of Oscars won  \
# Film
# 2001                               1968                1
# Metropolis                         1927              NaN
# Blade Runner                       1982              NaN
# ...

# %%
# https://docs.google.com/spreadsheets/d/1N5_Oaw3gwXI4TuLEPZB6ShgzZolkDVS-YwdEnorkxWA/edit#gid=0
url='https://docs.google.com/spreadsheets/d/1N5_Oaw3gwXI4TuLEPZB6ShgzZolkDVS-YwdEnorkxWA/export?gid=1583523635&format=csv'
df=pd.read_csv(url)
df.head()
# Out:
#    Year  Customers
# 0  2550       1084
# 1  2551       1006
# 2  2552       1393
# 3  2553       1567
# 4  2554       1421

# %%
#https://docs.google.com/spreadsheets/d/1Jf_1qjjwa_gUaNIihdo4-F4yYCruum1m25C0RcnzH8E/edit#gid=1141604343
url="https://docs.google.com/spreadsheets/d/1Jf_1qjjwa_gUaNIihdo4-F4yYCruum1m25C0RcnzH8E/export?gid=1141604343&format=csv"
df=pd.read_csv(url)
df.head()
# Out:
#             ประทับเวลา     คะแนน     ชื่อ-นามสกุล หลักสูตร (สาขาวิชา)  \
# 0  18/6/2019, 16:23:41  27 / 100  กมลศักดิ์ ภาโสม        ระบบสารสนเทศ
# 1  18/6/2019, 16:50:30  18 / 100           oooppp        ระบบสารสนเทศ
# 2  20/6/2019, 13:04:27  34 / 100   ฐานทัพ มิ่งทอง        ระบบสารสนเทศ
# 3  20/6/2019, 13:11:43  29 / 100          วรรณิดา           การจัดการ
# 4  20/6/2019, 13:22:34  22 / 100    สรรธพร ชูดำดี           การจัดการ
#
#      เบอร์ติดต่อ                    อีเมล                   ชั้นปี  \
# 0     0864147752  katearrerawan@gmail.com     ปี 3 (เทียบโอน-สมทบ)
# 1  0888888888888  katearrerawan@gmail.com  ปี 3 (เทียบโอน-ภาคปกิต)
# 2     0924783923        bizabbt@gmail.com  ปี 3 (เทียบโอน-ภาคปกิต)
# 3     0954792639  Wannidaritsri@gmail.com     ปี 3 (เทียบโอน-สมทบ)
# 4     0918462214      Dynadin@outlook.com  ปี 3 (เทียบโอน-ภาคปกิต)
#
#   1. Through this telescope you could see what look like on……. Mars.  \
# 0                                               2. a
# ...
