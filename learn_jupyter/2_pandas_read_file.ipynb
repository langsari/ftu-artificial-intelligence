# %% [markdown]
# # read CSV, TSV, Excel, Zip, FWF

# %%
#เรียนรู้ การอ่านไฟล์ชนิดต่างๆ
from IPython.display import IFrame, YouTubeVideo, SVG, HTML
YouTubeVideo('71wHi9O0QUQ', 400,300)

# %% [markdown]
# ---
# * author: Prasert Kanawattanachai
# * e-mail: prasert.k@chula.ac.th
# * [Chulalongkorn Business School, Thailand](https://www.cbs.chula.ac.th/en/home/)
# ---

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('71wHi9O0QUQ', width=720, height=405)

# %%
import pandas as pd

# %%
url = 'https://github.com/AddisonGauss/NbaData2015-2016/raw/master/nbasalaries.csv'
df=pd.read_csv(url)
df
# Out:
#      Unnamed: 0   RK                  Player                 TEAM  \
# 0             0    1             Kobe Bryant   Los Angeles Lakers
# 1             1    2            LeBron James  Cleveland Cavaliers
# 2             2    3         Carmelo Anthony      New York Knicks
# 3             3    4           Dwight Howard      Houston Rockets
# 4             4    5              Chris Bosh           Miami Heat
# ..          ...  ...                     ...                  ...
# 415         415  416         Orlando Johnson         Phoenix Suns
# 416         416  417            Phil Pressey         Phoenix Suns
# 417         417  418         Elliot Williams    Memphis Grizzlies
# 418         418  419          Cory Jefferson         Phoenix Suns
# 419         419  420  Thanasis Antetokounmpo      New York Knicks
#
#            SALARY
# 0    $25,000,000
# 1    $22,970,500
# 2    $22,875,000
# 3    $22,359,364
# 4    $22,192,730
# ..            ...
# 415      $55,722
# 416      $55,722
# 417      $55,722
# 418      $49,709
# 419      $30,888
#
# [420 rows x 5 columns]

# %%
url = 'https://github.com/prasertcbs/test/raw/master/top_movies.tsv'
df=pd.read_csv(url, sep='\t')
df
# Out:
#    Rank                                              Title  Worldwide gross  \
# 0     1                                             Avatar  $2,782,275,172
# 1     2                     Titanic film currently playing  $2,175,778,696
# 2     3      Harry Potter and the Deathly Hallows – Part 2  $1,328,111,219
# 3     4                     Transformers: Dark of the Moon  $1,123,746,996
# 4     5      The Lord of the Rings: The Return of the King  $1,119,929,521
# 5     6         Pirates of the Caribbean: Dead Man's Chest  $1,066,179,725
# 6     7                                        Toy Story 3  $1,063,171,911
# 7     8        Pirates of the Caribbean: On Stranger Tides  $1,043,871,802
# 8     9  Star Wars Episode I: The Phantom Menace film c...  $1,026,281,382
# 9    10                                Alice in Wonderland  $1,024,299,904
#
#    Year
# 0  2009
# 1  1997
# 2  2011
# 3  2011
# 4  2003
# 5  2006
# 6  2010
# 7  2011
# 8  1999
# 9  2010

# %%
url = 'https://github.com/prasertcbs/test/raw/master/iris.xlsx'
df=pd.read_excel(url)
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# 16            5.4          3.9           1.3          0.4     setosa
# 17            5.1          3.5           1.4          0.3     setosa
# 18            5.7          3.8           1.7          0.3     setosa
# 19            5.1          3.8           1.5          0.3     setosa
# 20            5.4          3.4           1.7          0.2     setosa
# 21            5.1          3.7           1.5          0.4     setosa
# 22            4.6          3.6           1.0          0.2     setosa
# 23            5.1          3.3           1.7          0.5     setosa
# 24            4.8          3.4           1.9          0.2     setosa
# 25            5.0          3.0           1.6          0.2     setosa
# 26            5.0          3.4           1.6          0.4     setosa
# 27            5.2          3.5           1.5          0.2     setosa
# 28            5.2          3.4           1.4          0.2     setosa
# 29            4.7          3.2           1.6          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 120           6.9          3.2           5.7          2.3  virginica
# 121           5.6          2.8           4.9          2.0  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 123           6.3          2.7           4.9          1.8  virginica
# 124           6.7          3.3           5.7          2.1  virginica
# 125           7.2          3.2           6.0          1.8  virginica
# 126           6.2          2.8           4.8          1.8  virginica
# 127           6.1          3.0           4.9          1.8  virginica
# 128           6.4          2.8           5.6          2.1  virginica
# 129           7.2          3.0           5.8          1.6  virginica
# 130           7.4          2.8           6.1          1.9  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 132           6.4          2.8           5.6          2.2  virginica
# 133           6.3          2.8           5.1          1.5  virginica
# 134           6.1          2.6           5.6          1.4  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 136           6.3          3.4           5.6          2.4  virginica
# 137           6.4          3.1           5.5          1.8  virginica
# 138           6.0          3.0           4.8          1.8  virginica
# 139           6.9          3.1           5.4          2.1  virginica
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
url = 'https://github.com/prasertcbs/test/raw/master/thai_provinces.zip'
df=pd.read_csv(url)
df
# Out:
#    provinceID   provinceTh         provinceEn regionID    areaKm2
# 0          นม   นครราชสีมา  Nakhon Ratchasima       NE  20493.964
# 1          ชม    เชียงใหม่         Chiang Mai        N  20107.057
# 2          กจ    กาญจนบุรี       Kanchanaburi        C  19483.148
# 3          ตก          ตาก                Tak        N  16406.650
# 4          อบ  อุบลราชธานี   Ubon Ratchathani       NE  16112.650
# ..        ...          ...                ...      ...        ...
# 72         สห    สิงห์บุรี          Sing Buri        C    822.478
# 73         นบ      นนทบุรี         Nonthaburi        C    622.303
# 74         ภก       ภูเก็ต             Phuket        S    543.034
# 75         สส  สมุทรสงคราม    Samut Songkhram        C    416.707
# 76         บก       บึงกาฬ          Bueng Kan       NE   4305.000
#
# [77 rows x 5 columns]

# %% [markdown]
# ## fwf = fixed width format

# %%
url = 'https://github.com/prasertcbs/test/raw/master/fwf_no_header.txt'
df=pd.read_fwf(url, widths=[5, 7, 1], names=['student_id', 'course_id', 'grade'])
df
# Out:
#   student_id course_id grade
# 0      S8080   C762394     D
# 1      S2942   C688774     C
# 2      S4472   C290905     D
# 3      S2616   C237794     B
# 4      S2641   C343581     A
# 5      S9055   C191393     B
# 6      S1627   C317822     C
# 7      S4236   C142563     B
# 8      S1932   C754223     B
# 9      S0185   C486927     D
