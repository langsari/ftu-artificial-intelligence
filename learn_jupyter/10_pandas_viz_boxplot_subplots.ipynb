# %%
#วิดีโอสอน pandas Boxplot subplots
from IPython.display import IFrame, YouTubeVideo, SVG, HTML
YouTubeVideo('G4JYU2zG34E', 400,300)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
print(f'pandas version: {pd.__version__}')
# Out:
# pandas version: 0.23.4

# %%
df=pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/mpg.csv')
df.sample(5)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 34     chevrolet               malibu    3.1  1999    6    auto(l4)   f   18
# 69         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
# 175       toyota          4runner 4wd    3.4  1999    6    auto(l4)   4   15
# 131   land rover          range rover    4.2  2008    8    auto(s6)   4   12
# 232   volkswagen               passat    2.8  1999    6  manual(m5)   f   18
#
#      hwy fl    class
# 34    26  r  midsize
# 69    12  e   pickup
# 175   19  r      suv
# 131   18  r      suv
# 232   26  p  midsize

# %%
df.boxplot()

# %%
df.boxplot(column=['cty', 'hwy'])

# %%
df.boxplot(column=['displ', 'cyl'])

# %%
df.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %%
for column in ['displ', 'cyl', 'cty', 'hwy']:
  df.boxplot(column)
  plt.show()

# %%
fig, ax=plt.subplots(1, 4, figsize=(16, 4))
columns=['displ', 'cyl', 'cty', 'hwy']
for i, column in enumerate(columns):
#     print(i, column)
    df.boxplot(column, ax=ax[i])

# %%
columns=['displ', 'cyl', 'cty', 'hwy']
nrows=1
ncols=math.ceil(len(columns) / nrows)
fig, ax = plt.subplots(nrows, ncols, figsize=(ncols*3,nrows*4))
print(ax.shape)
col_idx=0
if nrows==1 or ncols==1:
    for c in range(ax.size):
        if col_idx < len(columns):
            df.boxplot(columns[col_idx], ax=ax[c])
            col_idx+=1
else:   
    for r in range(nrows):
        for c in range(ncols):
            if col_idx < len(columns):
                df.boxplot(columns[col_idx], ax=ax[r, c])
                col_idx+=1
# Out:
# (4,)

# %%
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
df.columns.str.match('year')
# Out:
# array([False, False, False,  True, False, False, False, False, False,
#        False, False])

# %%
df.columns[~df.columns.str.match('year')]
# Out:
# Index(['manufacturer', 'model', 'displ', 'cyl', 'trans', 'drv', 'cty', 'hwy',
#        'fl', 'class'],
#       dtype='object')

# %%
df.select_dtypes('number')
# Out:
#      displ  year  cyl  cty  hwy
# 0      1.8  1999    4   18   29
# 1      1.8  1999    4   21   29
# 2      2.0  2008    4   20   31
# 3      2.0  2008    4   21   30
# 4      2.8  1999    6   16   26
# 5      2.8  1999    6   18   26
# 6      3.1  2008    6   18   27
# 7      1.8  1999    4   18   26
# 8      1.8  1999    4   16   25
# 9      2.0  2008    4   20   28
# 10     2.0  2008    4   19   27
# 11     2.8  1999    6   15   25
# 12     2.8  1999    6   17   25
# 13     3.1  2008    6   17   25
# 14     3.1  2008    6   15   25
# 15     2.8  1999    6   15   24
# 16     3.1  2008    6   17   25
# 17     4.2  2008    8   16   23
# 18     5.3  2008    8   14   20
# 19     5.3  2008    8   11   15
# 20     5.3  2008    8   14   20
# 21     5.7  1999    8   13   17
# 22     6.0  2008    8   12   17
# 23     5.7  1999    8   16   26
# 24     5.7  1999    8   15   23
# 25     6.2  2008    8   16   26
# 26     6.2  2008    8   15   25
# 27     7.0  2008    8   15   24
# 28     5.3  2008    8   14   19
# 29     5.3  2008    8   11   14
# ..     ...   ...  ...  ...  ...
# 204    3.4  1999    6   15   19
# 205    4.0  2008    6   15   18
# 206    4.0  2008    6   16   20
# 207    2.0  1999    4   21   29
# 208    2.0  1999    4   19   26
# 209    2.0  2008    4   21   29
# 210    2.0  2008    4   22   29
# 211    2.8  1999    6   17   24
# 212    1.9  1999    4   33   44
# 213    2.0  1999    4   21   29
# 214    2.0  1999    4   19   26
# 215    2.0  2008    4   22   29
# 216    2.0  2008    4   21   29
# 217    2.5  2008    5   21   29
# 218    2.5  2008    5   21   29
# 219    2.8  1999    6   16   23
# 220    2.8  1999    6   17   24
# 221    1.9  1999    4   35   44
# 222    1.9  1999    4   29   41
# 223    2.0  1999    4   21   29
# 224    2.0  1999    4   19   26
# 225    2.5  2008    5   20   28
# 226    2.5  2008    5   20   29
# 227    1.8  1999    4   21   29
# 228    1.8  1999    4   18   29
# 229    2.0  2008    4   19   28
# 230    2.0  2008    4   21   29
# 231    2.8  1999    6   16   26
# 232    2.8  1999    6   18   26
# 233    3.6  2008    6   17   26
#
# [234 rows x 5 columns]

# %%
df[df.columns[~df.columns.str.match('year')]].select_dtypes('number')
# Out:
#      displ  cyl  cty  hwy
# 0      1.8    4   18   29
# 1      1.8    4   21   29
# 2      2.0    4   20   31
# 3      2.0    4   21   30
# 4      2.8    6   16   26
# 5      2.8    6   18   26
# 6      3.1    6   18   27
# 7      1.8    4   18   26
# 8      1.8    4   16   25
# 9      2.0    4   20   28
# 10     2.0    4   19   27
# 11     2.8    6   15   25
# 12     2.8    6   17   25
# 13     3.1    6   17   25
# 14     3.1    6   15   25
# 15     2.8    6   15   24
# 16     3.1    6   17   25
# 17     4.2    8   16   23
# 18     5.3    8   14   20
# 19     5.3    8   11   15
# 20     5.3    8   14   20
# 21     5.7    8   13   17
# 22     6.0    8   12   17
# 23     5.7    8   16   26
# 24     5.7    8   15   23
# 25     6.2    8   16   26
# 26     6.2    8   15   25
# 27     7.0    8   15   24
# 28     5.3    8   14   19
# 29     5.3    8   11   14
# ..     ...  ...  ...  ...
# 204    3.4    6   15   19
# 205    4.0    6   15   18
# 206    4.0    6   16   20
# 207    2.0    4   21   29
# 208    2.0    4   19   26
# 209    2.0    4   21   29
# 210    2.0    4   22   29
# 211    2.8    6   17   24
# 212    1.9    4   33   44
# 213    2.0    4   21   29
# 214    2.0    4   19   26
# 215    2.0    4   22   29
# 216    2.0    4   21   29
# 217    2.5    5   21   29
# 218    2.5    5   21   29
# 219    2.8    6   16   23
# 220    2.8    6   17   24
# 221    1.9    4   35   44
# 222    1.9    4   29   41
# 223    2.0    4   21   29
# 224    2.0    4   19   26
# 225    2.5    5   20   28
# 226    2.5    5   20   29
# 227    1.8    4   21   29
# 228    1.8    4   18   29
# 229    2.0    4   19   28
# 230    2.0    4   21   29
# 231    2.8    6   16   26
# 232    2.8    6   18   26
# 233    3.6    6   17   26
#
# [234 rows x 4 columns]

# %%
dg=df[df.columns[~df.columns.str.match('year')]].select_dtypes('number')
dg.columns
# Out:
# Index(['displ', 'cyl', 'cty', 'hwy'], dtype='object')

# %%
# columns=['displ', 'cyl', 'cty', 'hwy']
columns=dg.columns
nrows=1
ncols=math.ceil(len(columns) / nrows)
fig, ax = plt.subplots(nrows, ncols, figsize=(ncols*3,nrows*4))
# print(ax.shape)
col_idx=0
if nrows==1 or ncols==1:
    for c in range(ax.size):
        if col_idx < len(columns):
            df.boxplot(columns[col_idx], ax=ax[c])
            col_idx+=1
else:   
    for r in range(nrows):
        for c in range(ncols):
            if col_idx < len(columns):
                df.boxplot(columns[col_idx], ax=ax[r, c])
                col_idx+=1
