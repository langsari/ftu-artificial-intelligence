# %% [markdown]
# # DatetimeIndex/Time Series

# %%
#เรียนรู้ การเขียนpython วิเคราะห์ข้อมูลด้วยอัลกอริทึม  TimeSeries (DatetimeIndex)
from IPython.display import IFrame, YouTubeVideo, SVG, HTML
YouTubeVideo('vc-_oaJhU2I', 400,300)

# %%
import pandas as pd
print(f'pandas version: {pd.__version__}')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# pandas version: 0.23.0

# %%
url='https://github.com/prasertcbs/basic-dataset/raw/master/OPEC_daily_oilprice.csv'
df = pd.read_csv(url, index_col='Date', parse_dates=True)
df.head()
# Out:
#             OilPrice
# Date
# 2018-06-01     74.23
# 2018-05-31     75.17
# 2018-05-30     73.72
# 2018-05-29     72.91
# 2018-05-28     73.37

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3979 entries, 2018-06-01 to 2003-01-02
# Data columns (total 1 columns):
# OilPrice    3979 non-null float64
# dtypes: float64(1)
# memory usage: 62.2 KB

# %%
df.sort_index(inplace=True)

# %%
df.head()
# Out:
#             OilPrice
# Date
# 2003-01-02     30.05
# 2003-01-03     30.83
# 2003-01-06     30.71
# 2003-01-07     29.72
# 2003-01-08     28.86

# %%
df.tail()
# Out:
#             OilPrice
# Date
# 2018-05-28     73.37
# 2018-05-29     72.91
# 2018-05-30     73.72
# 2018-05-31     75.17
# 2018-06-01     74.23

# %%
df
# Out:
#             OilPrice
# Date
# 2003-01-02     30.05
# 2003-01-03     30.83
# 2003-01-06     30.71
# 2003-01-07     29.72
# 2003-01-08     28.86
# 2003-01-09     29.51
# 2003-01-10     29.82
# 2003-01-13     29.82
# 2003-01-14     30.21
# 2003-01-15     30.66
# 2003-01-16     30.87
# 2003-01-17     31.02
# 2003-01-20     31.21
# 2003-01-21     30.90
# 2003-01-22     30.89
# 2003-01-23     30.18
# 2003-01-24     30.56
# 2003-01-27     30.16
# 2003-01-28     29.83
# 2003-01-29     30.30
# 2003-01-30     30.58
# 2003-01-31     30.71
# 2003-02-03     30.29
# 2003-02-04     29.98
# 2003-02-05     30.52
# 2003-02-06     30.77
# 2003-02-07     31.25
# 2003-02-10     31.38
# 2003-02-11     31.35
# 2003-02-12     31.30
# ...              ...
# 2018-04-23     70.51
# 2018-04-24     71.34
# 2018-04-25     70.50
# 2018-04-26     71.00
# 2018-04-27     71.24
# 2018-04-30     71.01
# 2018-05-01     70.57
# 2018-05-02     70.46
# 2018-05-03     70.64
# 2018-05-04     70.97
# 2018-05-07     72.43
# ...

# %%
pd.set_option('max_rows', 10)

# %%
df
# Out:
#             OilPrice
# Date
# 2003-01-02     30.05
# 2003-01-03     30.83
# 2003-01-06     30.71
# 2003-01-07     29.72
# 2003-01-08     28.86
# ...              ...
# 2018-05-28     73.37
# 2018-05-29     72.91
# 2018-05-30     73.72
# 2018-05-31     75.17
# 2018-06-01     74.23
#
# [3979 rows x 1 columns]

# %%
df['2017']
# Out:
#             OilPrice
# Date
# 2017-01-03     53.13
# 2017-01-04     52.71
# 2017-01-05     53.02
# 2017-01-06     53.50
# 2017-01-09     52.85
# ...              ...
# 2017-12-22     62.66
# 2017-12-26     63.07
# 2017-12-27     64.24
# 2017-12-28     64.17
# 2017-12-29     64.47
#
# [257 rows x 1 columns]

# %%
df['2015':'2017'] # inclusive
# Out:
#             OilPrice
# Date
# 2015-01-02     51.78
# 2015-01-05     48.87
# 2015-01-06     46.57
# 2015-01-07     44.79
# 2015-01-08     45.68
# ...              ...
# 2017-12-22     62.66
# 2017-12-26     63.07
# 2017-12-27     64.24
# 2017-12-28     64.17
# 2017-12-29     64.47
#
# [775 rows x 1 columns]

# %%
df[:'2017']
# Out:
#             OilPrice
# Date
# 2003-01-02     30.05
# 2003-01-03     30.83
# 2003-01-06     30.71
# 2003-01-07     29.72
# 2003-01-08     28.86
# ...              ...
# 2017-12-22     62.66
# 2017-12-26     63.07
# 2017-12-27     64.24
# 2017-12-28     64.17
# 2017-12-29     64.47
#
# [3871 rows x 1 columns]

# %%
df['2017'].mean()
# Out:
# OilPrice    52.429611
# dtype: float64

# %%
df['2017-01']
# Out:
#             OilPrice
# Date
# 2017-01-03     53.13
# 2017-01-04     52.71
# 2017-01-05     53.02
# 2017-01-06     53.50
# 2017-01-09     52.85
# ...              ...
# 2017-01-25     52.14
# 2017-01-26     52.91
# 2017-01-27     52.88
# 2017-01-30     52.78
# 2017-01-31     52.19
#
# [21 rows x 1 columns]

# %%
df['2017-01':'2017-06']
# Out:
#             OilPrice
# Date
# 2017-01-03     53.13
# 2017-01-04     52.71
# 2017-01-05     53.02
# 2017-01-06     53.50
# 2017-01-09     52.85
# ...              ...
# 2017-06-26     43.14
# 2017-06-27     44.23
# 2017-06-28     44.48
# 2017-06-29     45.36
# 2017-06-30     45.63
#
# [128 rows x 1 columns]

# %%
df['2017-01'].mean()
# Out:
# OilPrice    52.397143
# dtype: float64

# %%
df['2017-01-12':'2017-01-20']
# Out:
#             OilPrice
# Date
# 2017-01-12     52.30
# 2017-01-13     52.64
# 2017-01-16     52.17
# 2017-01-17     52.60
# 2017-01-18     52.22
# 2017-01-19     51.45
# 2017-01-20     51.80

# %%
# df['2018-03-05']

# %%
df['2018-03-05':'2018-03-05']
# Out:
#             OilPrice
# Date
# 2018-03-05     62.87

# %%
df.resample('Y').mean()
# Out:
#              OilPrice
# Date
# 2003-12-31  28.123735
# 2004-12-31  36.009115
# 2005-12-31  50.707248
# 2006-12-31  61.080584
# 2007-12-31  69.076705
# ...               ...
# 2014-12-31  96.133062
# 2015-12-31  49.504903
# 2016-12-31  40.759035
# 2017-12-31  52.429611
# 2018-12-31  67.545370
#
# [16 rows x 1 columns]

# %%
df.resample('Q').mean()
# Out:
#              OilPrice
# Date
# 2003-03-31  30.452540
# 2003-06-30  25.878437
# 2003-09-30  27.430758
# 2003-12-31  28.791250
# 2004-03-31  30.770938
# ...               ...
# 2017-06-30  48.472969
# 2017-09-30  49.977846
# 2017-12-31  59.352187
# 2018-03-31  64.749524
# 2018-06-30  71.459556
#
# [62 rows x 1 columns]

# %%
df.resample('M').mean()
# Out:
#              OilPrice
# Date
# 2003-01-31  30.336364
# 2003-02-28  31.643500
# 2003-03-31  29.440000
# 2003-04-30  25.239048
# 2003-05-31  25.629545
# ...               ...
# 2018-02-28  63.477500
# 2018-03-31  63.757619
# 2018-04-30  68.425238
# 2018-05-31  74.109565
# 2018-06-30  74.230000
#
# [186 rows x 1 columns]

# %%
df.resample('M').mean().plot(kind='line');

# %%
df['2015'].resample('Q').mean().plot(kind='line');

# %%
df['2015':'2017'].resample('Q').mean().plot(kind='line');

# %%
df['2008':].resample('Q').mean().plot(kind='line');
