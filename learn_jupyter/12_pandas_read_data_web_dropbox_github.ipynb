# %%
#เรียนรู้ การอ่านไฟล์หรือข้อมูลจากเว็บไซต์
from IPython.display import IFrame, YouTubeVideo, SVG, HTML
YouTubeVideo('Wo7tu3-Ltf4', 400,300)

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 0.25.1

# %% [markdown]
# ## read data from web

# %%
df=pd.read_csv('https://spotifycharts.com/regional/global/daily/latest/download')
df.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-4-021298fc8b4f> in <module>
# ----> 1 df=pd.read_csv('https://spotifycharts.com/regional/global/daily/latest/download')
#       2 df.head()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438     # See https://github.com/python/mypy/issues/1297
#     439     fp_or_buf, _, compression, should_close = get_filepath_or_buffer(
# --> 440         filepath_or_buffer, encoding, compression
#     441     )
#     442     kwds["compression"] = compression
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     194
#     195     if _is_url(filepath_or_buffer):
# --> 196         req = urlopen(filepath_or_buffer)
#     197         content_encoding = req.headers.get("Content-Encoding", None)
#     198         if content_encoding == "gzip":
#
# ~/anaconda3/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/anaconda3/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~/anaconda3/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/anaconda3/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %%
df=pd.read_excel('http://infographics.economist.com/2018/databank/BMFile2000toJan2018.xls')
df.head()
# Out:
#      Country  local_price  dollar_ex  dollar_price  dollar_ppp  \
# 0  Argentina        75.00  18.937500      3.960396   14.204545
# 1  Australia         5.90   1.253683      4.706135    1.117424
# 2     Brazil        16.50   3.227900      5.111683    3.125000
# 3    Britain         3.19   0.722857      4.413046    0.604167
# 4     Canada         6.55   1.245900      5.257244    1.240530
#
#    dollar_valuation  dollar_adj_valuation  euro_adj_valuation  \
# 0        -24.992499             18.650590            5.870471
# 1        -10.868655             -6.388069          -16.471218
# 2         -3.187831             60.962604           43.624964
# 3        -16.419583             -2.455560          -12.962289
# 4         -0.430989             13.847882            1.585073
#
#    sterling_adj_valuation  yen_adj_valuation  yuan_adj_valuation
# 0               21.637471          54.674121           17.830085
# 1               -4.031504          22.033470           -7.035424
# 2               65.014638         109.832495           59.849499
# 3                0.000000          27.159928           -3.130110
# 4               16.713862          48.413262           13.060589

# %% [markdown]
# ## read data from Dropbox

# %%
df=pd.read_csv('https://www.dropbox.com/s/wc6sp4gryezgx1j/exercise.csv?dl=1')
df.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
df=pd.read_excel('https://www.dropbox.com/s/un79x1v0cimy3ky/mpg2008.xlsx?dl=1')
df.head()
# Out:
#   manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0         audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 1         audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 2         audi          a4    3.1  2008    6    auto(av)   f   18   27  p
# 3         audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
# 4         audi  a4 quattro    2.0  2008    4    auto(s6)   4   19   27  p
#
#      class
# 0  compact
# 1  compact
# 2  compact
# 3  compact
# 4  compact

# %% [markdown]
# ## read data from github

# %%
df=pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/msleep.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0e08fdf083de> in <module>
# ----> 1 df=pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/msleep.csv')
#       2 df.head()
#
# NameError: name 'pd' is not defined

# %%
df=pd.read_excel('https://github.com/prasertcbs/tutorial/raw/master/BornInGeneration.xlsx')
df.head()
# Out:
#    empID     fname         lname sex        dob          position department  \
# 0    604    กันตภณ     ซ่อนกลิ่น   M 1994-03-05         ผู้จัดการ         HR
# 1    607    เกศินี       สายหยุด   F 1968-12-06  ผู้ช่วยผู้จัดการ        FIN
# 2    486  ชัชลัญญา        ลั่นทม   F 1987-06-01  ผู้ช่วยผู้จัดการ        FIN
# 3    229   ชาติไทย  เสี้ยวดอกแดง   M 1991-07-27   พนักงานระดับต้น        MKT
# 4    901    โชติมา        อรคนธ์   F 1974-08-21      รองผู้จัดการ        MKT
#
#    salary  join_date
# 0   13000 2016-02-28
# 1   40000 1987-11-30
# 2   25000 2009-05-26
# 3   39000 2015-07-21
# 4   82500 2007-09-18

# %% [markdown]
# ## read from local hard drive

# %%
df=pd.read_csv('data/Auto.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-a2469da43071> in <module>
# ----> 1 df=pd.read_csv('data/Auto.csv')
#       2 df.head()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'data/Auto.csv' does not exist: b'data/Auto.csv'

# %% [markdown]
# # Read data From OneDrive

# %%
#oneDrive <iframe src="https://onedrive.live.com/embed?cid=D2C6DFBFAF04B2D0&resid=D2C6DFBFAF04B2D0%21386&authkey=ABzqVPLYjHQXLhw&em=2" width="402" height="346" frameborder="0" scrolling="no"></iframe>
df=pd.read_excel('https://onedrive.live.com/download?cid=D2C6DFBFAF04B2D0&resid=D2C6DFBFAF04B2D0%21386&authkey=ABzqVPLYjHQXLhw&em=2')
df.head()
# Out:
#                ประทับเวลา  คะแนน     ชื่อ-นามสกุล หลักสูตร (สาขาวิชา)  \
# 0 2019-06-18 16:23:41.186     27  กมลศักดิ์ ภาโสม        ระบบสารสนเทศ
# 1 2019-06-18 16:50:29.673     18           oooppp        ระบบสารสนเทศ
# 2 2019-06-20 13:04:27.057     34   ฐานทัพ มิ่งทอง        ระบบสารสนเทศ
# 3 2019-06-20 13:11:43.023     29          วรรณิดา           การจัดการ
# 4 2019-06-20 13:22:33.553     22    สรรธพร ชูดำดี           การจัดการ
#
#      เบอร์ติดต่อ                    อีเมล                   ชั้นปี  \
# 0     0864147752  katearrerawan@gmail.com     ปี 3 (เทียบโอน-สมทบ)
# 1  0888888888888  katearrerawan@gmail.com  ปี 3 (เทียบโอน-ภาคปกิต)
# 2     0924783923        bizabbt@gmail.com  ปี 3 (เทียบโอน-ภาคปกิต)
# 3     0954792639  Wannidaritsri@gmail.com     ปี 3 (เทียบโอน-สมทบ)
# 4     0918462214      Dynadin@outlook.com  ปี 3 (เทียบโอน-ภาคปกิต)
#
#   1. Through this telescope you could see what look like on……. Mars.  \
# 0                                               2. a
# 1                                              3. an
# 2                                             4. the
# 3                                             4. the
# 4                                              3. an
#
#   2. Excuse me, I want to buy…………pepper grinders.  \
# 0                                           2. an
# 1                                            3. a
# 2                                         4. this
# 3                                            3. a
# 4                                            3. a
#
#   3. I have a doctor’s appointment…….May 10.  ...  \
# 0                                      2. on  ...
# 1                                      3. at  ...
# 2                                      3. at  ...
# 3                                      3. at  ...
# 4                                      1. in  ...
#
#   91. You can contact Instant Service………………………………  \
# 0                      2. twenty-four hours a day
# 1         3. in the hotel lobby next to the clock
# 2         3. in the hotel lobby next to the clock
# 3                      2. twenty-four hours a day
# 4                      2. twenty-four hours a day
#
#   92. There is a variety of drinks and snacks ……………………. .  \
# 0       2. that are removed from your room every day
# 1   3. that you can have and pay with your room bill
# 2                      1. in the hotel’s private bar
# 3   3. that you can have and pay with your room bill
# 4                      1. in the hotel’s private bar
#
#   93. There is ……………. Internet access in the hotel room.  \
# 0                                            2. free
# 1                                           3. basic
# 2                                            2. free
# 3                                           3. basic
# 4                                            2. free
#
#     94. What do you have to do if you want a coffee?  \
# 0            2. Put money in a machine in your room.
# 1  3. Follow the directions to the nearest coffee...
# 2  4. Have it for free in the lobby early in the ...
# 3  3. Follow the directions to the nearest coffee...
# 4  4. Have it for free in the lobby early in the ...
#
#   95. To enter the fitness Center, you need …………………. .  \
# 0                       2. to ask for a specific key
# 1                3. to be a guest on the third floor
# 2                              1. your room key card
# 3               4. to go between 6:00 AM and 8:00 PM
# 4                       2. to ask for a specific key
#
#                     96. The in-room safe is ……………… .  \
# 0   2. a box with a pin code to keep valuable things
# 1  3. a deposit box that you can get at the Recep...
# 2   2. a box with a pin code to keep valuable things
# 3  4. a personalized four-digit pin code to enter...
# 4  3. a deposit box that you can get at the Recep...
#
#   97. You might find that your room hasn’t been cleaned yet if you come back at ……………… .  \
# 0                               2. 2:00 PM on Friday
# 1                               3. 3:00 AM on Sunday
# 2                               1. 2:00 AM on Friday
# 3                               3. 3:00 AM on Sunday
# 4                               3. 3:00 AM on Sunday
#
#    98. If you need to clean your shoes, …………………….. .  \
# 0  2. call Instant Service for instructions on ho...
# 1  3. call Instant Service and they’ll clean them...
# 2  4. call Instant Service and they’ll collect th...
# 3  4. call Instant Service and they’ll collect th...
# 4  3. call Instant Service and they’ll clean them...
#
#   99. The hotel offers a selection of films that you can ……………………. .  \
# 0               2. watch for a daily amount of money
# 1                                   3. pay and watch
# 2         4. watch in the hotel’s entertainment area
# 3         4. watch in the hotel’s entertainment area
# 4                                   3. pay and watch
#
#   100. You should contact Instant Service if you need ………………….. .
# 0                                    2. fresh towels
# 1                                3. to wake up early
# 2                                    2. fresh towels
# 3                                    1. to check out
# 4                                3. to wake up early
#
# [5 rows x 107 columns]
